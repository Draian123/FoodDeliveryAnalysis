# %%
import pandas as pd

# Read the first CSV file (food_order.csv)
food_order_df = pd.read_csv("food_order.csv")

# Read the second CSV file (onlinefoods.csv)
onlinefoods_df = pd.read_csv("onlinefoods.csv")

# Now you have two separate DataFrames: food_order_df and onlinefoods_df
# You can work with them independently

# %%
food_order_df
# Out:
#       order_id  customer_id                        restaurant_name  \
# 0      1477147       337525                                Hangawi
# 1      1477685       358141              Blue Ribbon Sushi Izakaya
# 2      1477070        66393                            Cafe Habana
# 3      1477334       106968              Blue Ribbon Fried Chicken
# 4      1478249        76942                       Dirty Bird to Go
# ...        ...          ...                                    ...
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week     rating  \
# 0            Korean              30.75         Weekend  Not given
# ...

# %%
onlinefoods_df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
food_order_df.isna().sum()
# Out:
# order_id                 0
# customer_id              0
# restaurant_name          0
# cuisine_type             0
# cost_of_the_order        0
# day_of_the_week          0
# rating                   0
# food_preparation_time    0
# delivery_time            0
# dtype: int64

# %%
categorical_columns = food_order_df.select_dtypes(include='object').columns
numerical_columns = food_order_df._get_numeric_data().columns

# %%
numerical_columns
# Out:
# Index(['order_id', 'customer_id', 'cost_of_the_order', 'food_preparation_time',
#        'delivery_time'],
#       dtype='object')

# %%
categorical_columns
# Out:
# Index(['restaurant_name', 'cuisine_type', 'day_of_the_week', 'rating'], dtype='object')

# %%
food_order_df['restaurant_name'].value_counts()
# Out:
# restaurant_name
# Shake Shack                  219
# The Meatball Shop            132
# Blue Ribbon Sushi            119
# Blue Ribbon Fried Chicken     96
# Parm                          68
#                             ...
# Sushi Choshi                   1
# Dos Caminos Soho               1
# La Follia                      1
# Philippe Chow                  1
# 'wichcraft                     1
# Name: count, Length: 178, dtype: int64
